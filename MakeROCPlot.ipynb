# %%
# mount drive and change directory to project folder
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/520 Final Project"
# Out:
# /content/drive/.shortcut-targets-by-id/1KHBlsdIi36o_ikonJZ-usBVzGPrZlH0V/520 Final Project

# %%
import numpy as np

# %%
with open("baseline_fpr.npy", 'rb') as f:
  baseline_fpr = np.load(f)
with open("baseline_tpr.npy", 'rb') as f:
  baseline_tpr = np.load(f)
with open("logistic_fpr.npy", 'rb') as f:
  logistic_fpr = np.load(f)
with open("logistic_tpr.npy", 'rb') as f:
  logistic_tpr = np.load(f)
with open("cnn_fpr.npy", 'rb') as f:
  cnn_fpr = np.load(f)
with open("cnn_tpr.npy", 'rb') as f:
  cnn_tpr = np.load(f)
with open("pca_fpr.npy", 'rb') as f:
  pca_fpr = np.load(f)
with open("pca_tpr.npy", 'rb') as f:
  pca_tpr = np.load(f)
with open("rnn_fpr.npy", 'rb') as f:
  rnn_fpr = np.load(f)
with open("rnn_tpr.npy", 'rb') as f:
  rnn_tpr = np.load(f)
# add RNN stuff here later...

# %%
import matplotlib.pyplot as plt
plt.plot(baseline_fpr, baseline_tpr, label='Baseline Model')
plt.plot(logistic_fpr, logistic_tpr, label='Logistic Regression')
plt.plot(cnn_fpr, cnn_tpr, label='CNN')
plt.plot(pca_fpr, pca_tpr, label='Spectral PCA')
plt.plot(rnn_fpr, rnn_tpr, label='LSTM')
plt.legend()
plt.title('Middle C ROC Curve')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.show()
